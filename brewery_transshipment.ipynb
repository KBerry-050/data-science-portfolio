# %%
# import pulp
from pulp import LpVariable, LpProblem, LpMaximize, LpStatus, value, LpMinimize, GLPK

# Brewery Transshipment Problem - GOAL is to minimize shipping costs across the 57 paths

# PROBLEM 1

# define variables - # of units to ship from each brewery to packaging facility - 12 paths
B1_P1 = LpVariable("B1_P1", 0, None)
B1_P2 = LpVariable("B1_P2", 0, None)
B1_P3 = LpVariable("B1_P3", 0, None)
B2_P1 = LpVariable("B2_P1", 0, None)
B2_P2 = LpVariable("B2_P2", 0, None)
B2_P3 = LpVariable("B2_P3", 0, None)
B3_P1 = LpVariable("B3_P1", 0, None)
B3_P2 = LpVariable("B3_P2", 0, None)
B3_P3 = LpVariable("B3_P3", 0, None)
B4_P1 = LpVariable("B4_P1", 0, None)
B4_P2 = LpVariable("B4_P2", 0, None)
B4_P3 = LpVariable("B4_P3", 0, None)

# define variables - # of units to ship from each packaging facility to each demand point - 45 paths
P1_D1 = LpVariable("P1_D1", 0, None)
P1_D2 = LpVariable("P1_D2", 0, None)
P1_D3 = LpVariable("P1_D3", 0, None)
P1_D4 = LpVariable("P1_D4", 0, None)
P1_D5 = LpVariable("P1_D5", 0, None)
P1_D6 = LpVariable("P1_D6", 0, None)
P1_D7 = LpVariable("P1_D7", 0, None)
P1_D8 = LpVariable("P1_D8", 0, None)
P1_D9 = LpVariable("P1_D9", 0, None)
P1_D10 = LpVariable("P1_D10", 0, None)
P1_D11 = LpVariable("P1_D11", 0, None)
P1_D12 = LpVariable("P1_D12", 0, None)
P1_D13 = LpVariable("P1_D13", 0, None)
P1_D14 = LpVariable("P1_D14", 0, None)
P1_D15 = LpVariable("P1_D15", 0, None)
P2_D1 = LpVariable("P2_D1", 0, None)
P2_D2 = LpVariable("P2_D2", 0, None)
P2_D3 = LpVariable("P2_D3", 0, None)
P2_D4 = LpVariable("P2_D4", 0, None)
P2_D5 = LpVariable("P2_D5", 0, None)
P2_D6 = LpVariable("P2_D6", 0, None)
P2_D7 = LpVariable("P2_D7", 0, None)
P2_D8 = LpVariable("P2_D8", 0, None)
P2_D9 = LpVariable("P2_D9", 0, None)
P2_D10 = LpVariable("P2_D10", 0, None)
P2_D11 = LpVariable("P2_D11", 0, None)
P2_D12 = LpVariable("P2_D12", 0, None)
P2_D13 = LpVariable("P2_D13", 0, None)
P2_D14 = LpVariable("P2_D14", 0, None)
P2_D15 = LpVariable("P2_D15", 0, None)
P3_D1 = LpVariable("P3_D1", 0, None)
P3_D2 = LpVariable("P3_D2", 0, None)
P3_D3 = LpVariable("P3_D3", 0, None)
P3_D4 = LpVariable("P3_D4", 0, None)
P3_D5 = LpVariable("P3_D5", 0, None)
P3_D6 = LpVariable("P3_D6", 0, None)
P3_D7 = LpVariable("P3_D7", 0, None)
P3_D8 = LpVariable("P3_D8", 0, None)
P3_D9 = LpVariable("P3_D9", 0, None)
P3_D10 = LpVariable("P3_D10", 0, None)
P3_D11 = LpVariable("P3_D11", 0, None)
P3_D12 = LpVariable("P3_D12", 0, None)
P3_D13 = LpVariable("P3_D13", 0, None)
P3_D14 = LpVariable("P3_D14", 0, None)
P3_D15 = LpVariable("P3_D15", 0, None)


# define the problem - minimize total shipping costs
Brewery_prob = LpProblem("problem", LpMinimize)

# define flow constraints - brewery capacities
Brewery_prob += B1_P1+B1_P2+B1_P3 >= 100
Brewery_prob += B1_P1+B1_P2+B1_P3 <= 2000
Brewery_prob += B2_P1+B2_P2+B2_P3 >= 150
Brewery_prob += B2_P1+B2_P2+B2_P3 <= 2500
Brewery_prob += B3_P1+B3_P2+B3_P3 >= 200
Brewery_prob += B3_P1+B3_P2+B3_P3 <= 3500
Brewery_prob += B4_P1+B4_P2+B4_P3 >= 100
Brewery_prob += B4_P1+B4_P2+B4_P3 <= 2000

# define flow constraints - pkg facility capacities
Brewery_prob += B1_P1+B2_P1+B3_P1+B4_P1 >= 50
Brewery_prob += B1_P1+B2_P1+B3_P1+B4_P1 <= 500
Brewery_prob += B1_P2+B2_P2+B3_P2+B4_P2 >= 100
Brewery_prob += B1_P2+B2_P2+B3_P2+B4_P2 <= 1500
Brewery_prob += B1_P3+B2_P3+B3_P3+B4_P3 >= 150
Brewery_prob += B1_P3+B2_P3+B3_P3+B4_P3 <= 2500


# define flow constraints - demand points units ordered
Brewery_prob += P1_D1+P2_D1+P3_D1 == 48
Brewery_prob += P1_D2+P2_D2+P3_D2 == 84
Brewery_prob += P1_D3+P2_D3+P3_D3 == 64
Brewery_prob += P1_D4+P2_D4+P3_D4 == 106
Brewery_prob += P1_D5+P2_D5+P3_D5 == 47
Brewery_prob += P1_D6+P2_D6+P3_D6 == 57
Brewery_prob += P1_D7+P2_D7+P3_D7 == 64
Brewery_prob += P1_D8+P2_D8+P3_D8 == 93
Brewery_prob += P1_D9+P2_D9+P3_D9 == 74
Brewery_prob += P1_D10+P2_D10+P3_D10 == 41
Brewery_prob += P1_D11+P2_D11+P3_D11 == 61
Brewery_prob += P1_D12+P2_D12+P3_D12 == 42
Brewery_prob += P1_D13+P2_D13+P3_D13 == 57
Brewery_prob += P1_D14+P2_D14+P3_D14 == 70
Brewery_prob += P1_D15+P2_D15+P3_D15 == 41


# define objective function
Brewery_prob += 1.55*B1_P1+0.51*B1_P2+0.9*B1_P3+0.81*B2_P1+3.18*B2_P2+0.65*B2_P3+2.13*B3_P1+0.97*B3_P2+0.51*B3_P3+1.23*B4_P1+2.15*B4_P2+2.08*B4_P3+4.82*P1_D1+2.05*P1_D2+4.42*P1_D3+3.83*P1_D4+0.97*P1_D5+3.04*P1_D6+3.91*P1_D7+4.03*P1_D8+5.11*P1_D9+0.90*P1_D10+4.39*P1_D11+.85*P1_D12+2.81*P1_D13+3.94*P1_D14+1.04*P1_D15+1.83*P2_D1+4.03*P2_D2+3.95*P2_D3+4.21*P2_D4+4.78*P2_D5+3.2*P2_D6+1.88*P2_D7+2.96*P2_D8+5.11*P2_D9+2.67*P2_D10+4.14*P2_D11+1.22*P2_D12+5.1*P2_D13+3.47*P2_D14+1.92*P2_D15+2.66*P3_D1+.95*P3_D2+3.94*P3_D3+2.04*P3_D4+2.35*P3_D5+1.42*P3_D6+3.6*P3_D7+3.17*P3_D8+1.34*P3_D9+4.51*P3_D10+.74*P3_D11+.94*P3_D12+1.98*P3_D13+4.77*P3_D14+2.04*P3_D15

# solve the problem
Brewery_prob.writeLP("Brewery_prob.lp")
Brewery_prob.solve(GLPK(options=['--ranges','Brewery_prob.sen']))
print ("Status:", LpStatus[Brewery_prob.status])

for v in Brewery_prob.variables():
    print(v.name, "=", v.varValue)

print ("Objective", value(Brewery_prob.objective))
print ("")
# Out:
# Status: Optimal
# B1_P1 = 0.0
# B1_P2 = 100.0
# B1_P3 = 0.0
# B2_P1 = 0.0
# B2_P2 = 0.0
# B2_P3 = 150.0
# B3_P1 = 0.0
# B3_P2 = 0.0
# B3_P3 = 200.0
# B4_P1 = 100.0
# B4_P2 = 0.0
# B4_P3 = 0.0
# P1_D1 = 0.0
# P1_D10 = 41.0
# P1_D11 = 0.0
# P1_D12 = 42.0
# P1_D13 = 0.0
# P1_D14 = 0.0
# P1_D15 = 41.0
# P1_D2 = 0.0
# P1_D3 = 0.0
# P1_D4 = 0.0
# P1_D5 = 47.0
# P1_D6 = 0.0
# P1_D7 = 0.0
# P1_D8 = 0.0
# P1_D9 = 0.0
# P2_D1 = 48.0
# P2_D10 = 0.0
# P2_D11 = 0.0
# P2_D12 = 0.0
# P2_D13 = 0.0
# P2_D14 = 70.0
# P2_D15 = 0.0
# P2_D2 = 0.0
# P2_D3 = 0.0
# P2_D4 = 0.0
# P2_D5 = 0.0
# P2_D6 = 0.0
# P2_D7 = 64.0
# P2_D8 = 93.0
# P2_D9 = 0.0
# P3_D1 = 0.0
# P3_D10 = 0.0
# P3_D11 = 61.0
# P3_D12 = 0.0
# P3_D13 = 57.0
# P3_D14 = 0.0
# P3_D15 = 0.0
# P3_D2 = 84.0
# P3_D3 = 64.0
# P3_D4 = 106.0
# P3_D5 = 0.0
# P3_D6 = 57.0
# P3_D7 = 0.0
# P3_D8 = 0.0
# P3_D9 = 74.0
# Objective 2146.9700000000003

# %%
# import pandas and pulp
import pandas as pd
from pulp import LpVariable, LpProblem, LpMaximize, LpStatus, value, LpMinimize, GLPK

# Brewery Transshipment Problem - GOAL is to minimize shipping costs across the 57 paths

# PROBLEM 1 - SAME SOLUTION, DIFFERENT WAY OF PRESENTING RESULTS - INCLUDES SHADOW PRICES

# define variables - # of units to ship from each brewery to packaging facility - 12 paths
B1_P1 = LpVariable("B1_P1", 0, None)
B1_P2 = LpVariable("B1_P2", 0, None)
B1_P3 = LpVariable("B1_P3", 0, None)
B2_P1 = LpVariable("B2_P1", 0, None)
B2_P2 = LpVariable("B2_P2", 0, None)
B2_P3 = LpVariable("B2_P3", 0, None)
B3_P1 = LpVariable("B3_P1", 0, None)
B3_P2 = LpVariable("B3_P2", 0, None)
B3_P3 = LpVariable("B3_P3", 0, None)
B4_P1 = LpVariable("B4_P1", 0, None)
B4_P2 = LpVariable("B4_P2", 0, None)
B4_P3 = LpVariable("B4_P3", 0, None)

# define variables - # of units to ship from each packaging facility to each demand point - 45 paths
P1_D1 = LpVariable("P1_D1", 0, None)
P1_D2 = LpVariable("P1_D2", 0, None)
P1_D3 = LpVariable("P1_D3", 0, None)
P1_D4 = LpVariable("P1_D4", 0, None)
P1_D5 = LpVariable("P1_D5", 0, None)
P1_D6 = LpVariable("P1_D6", 0, None)
P1_D7 = LpVariable("P1_D7", 0, None)
P1_D8 = LpVariable("P1_D8", 0, None)
P1_D9 = LpVariable("P1_D9", 0, None)
P1_D10 = LpVariable("P1_D10", 0, None)
P1_D11 = LpVariable("P1_D11", 0, None)
P1_D12 = LpVariable("P1_D12", 0, None)
P1_D13 = LpVariable("P1_D13", 0, None)
P1_D14 = LpVariable("P1_D14", 0, None)
P1_D15 = LpVariable("P1_D15", 0, None)
P2_D1 = LpVariable("P2_D1", 0, None)
P2_D2 = LpVariable("P2_D2", 0, None)
P2_D3 = LpVariable("P2_D3", 0, None)
P2_D4 = LpVariable("P2_D4", 0, None)
P2_D5 = LpVariable("P2_D5", 0, None)
P2_D6 = LpVariable("P2_D6", 0, None)
P2_D7 = LpVariable("P2_D7", 0, None)
P2_D8 = LpVariable("P2_D8", 0, None)
P2_D9 = LpVariable("P2_D9", 0, None)
P2_D10 = LpVariable("P2_D10", 0, None)
P2_D11 = LpVariable("P2_D11", 0, None)
P2_D12 = LpVariable("P2_D12", 0, None)
P2_D13 = LpVariable("P2_D13", 0, None)
P2_D14 = LpVariable("P2_D14", 0, None)
P2_D15 = LpVariable("P2_D15", 0, None)
P3_D1 = LpVariable("P3_D1", 0, None)
P3_D2 = LpVariable("P3_D2", 0, None)
P3_D3 = LpVariable("P3_D3", 0, None)
P3_D4 = LpVariable("P3_D4", 0, None)
P3_D5 = LpVariable("P3_D5", 0, None)
P3_D6 = LpVariable("P3_D6", 0, None)
P3_D7 = LpVariable("P3_D7", 0, None)
P3_D8 = LpVariable("P3_D8", 0, None)
P3_D9 = LpVariable("P3_D9", 0, None)
P3_D10 = LpVariable("P3_D10", 0, None)
P3_D11 = LpVariable("P3_D11", 0, None)
P3_D12 = LpVariable("P3_D12", 0, None)
P3_D13 = LpVariable("P3_D13", 0, None)
P3_D14 = LpVariable("P3_D14", 0, None)
P3_D15 = LpVariable("P3_D15", 0, None)


# define the problem - minimize total shipping costs
Brewery_prob = LpProblem("problem", LpMinimize)

# define flow constraints - brewery capacities
Brewery_prob += B1_P1+B1_P2+B1_P3 >= 100
Brewery_prob += B1_P1+B1_P2+B1_P3 <= 2000
Brewery_prob += B2_P1+B2_P2+B2_P3 >= 150
Brewery_prob += B2_P1+B2_P2+B2_P3 <= 2500
Brewery_prob += B3_P1+B3_P2+B3_P3 >= 200
Brewery_prob += B3_P1+B3_P2+B3_P3 <= 3500
Brewery_prob += B4_P1+B4_P2+B4_P3 >= 100
Brewery_prob += B4_P1+B4_P2+B4_P3 <= 2000

# define flow constraints - pkg facility capacities
Brewery_prob += B1_P1+B2_P1+B3_P1+B4_P1 >= 50
Brewery_prob += B1_P1+B2_P1+B3_P1+B4_P1 <= 500
Brewery_prob += B1_P2+B2_P2+B3_P2+B4_P2 >= 100
Brewery_prob += B1_P2+B2_P2+B3_P2+B4_P2 <= 1500
Brewery_prob += B1_P3+B2_P3+B3_P3+B4_P3 >= 150
Brewery_prob += B1_P3+B2_P3+B3_P3+B4_P3 <= 2500


# define flow constraints - demand points units ordered
Brewery_prob += P1_D1+P2_D1+P3_D1 == 48
Brewery_prob += P1_D2+P2_D2+P3_D2 == 84
Brewery_prob += P1_D3+P2_D3+P3_D3 == 64
Brewery_prob += P1_D4+P2_D4+P3_D4 == 106
Brewery_prob += P1_D5+P2_D5+P3_D5 == 47
Brewery_prob += P1_D6+P2_D6+P3_D6 == 57
Brewery_prob += P1_D7+P2_D7+P3_D7 == 64
Brewery_prob += P1_D8+P2_D8+P3_D8 == 93
Brewery_prob += P1_D9+P2_D9+P3_D9 == 74
Brewery_prob += P1_D10+P2_D10+P3_D10 == 41
Brewery_prob += P1_D11+P2_D11+P3_D11 == 61
Brewery_prob += P1_D12+P2_D12+P3_D12 == 42
Brewery_prob += P1_D13+P2_D13+P3_D13 == 57
Brewery_prob += P1_D14+P2_D14+P3_D14 == 70
Brewery_prob += P1_D15+P2_D15+P3_D15 == 41


# define objective function
Brewery_prob += 1.55*B1_P1+0.51*B1_P2+0.9*B1_P3+0.81*B2_P1+3.18*B2_P2+0.65*B2_P3+2.13*B3_P1+0.97*B3_P2+0.51*B3_P3+1.23*B4_P1+2.15*B4_P2+2.08*B4_P3+4.82*P1_D1+2.05*P1_D2+4.42*P1_D3+3.83*P1_D4+0.97*P1_D5+3.04*P1_D6+3.91*P1_D7+4.03*P1_D8+5.11*P1_D9+0.90*P1_D10+4.39*P1_D11+.85*P1_D12+2.81*P1_D13+3.94*P1_D14+1.04*P1_D15+1.83*P2_D1+4.03*P2_D2+3.95*P2_D3+4.21*P2_D4+4.78*P2_D5+3.2*P2_D6+1.88*P2_D7+2.96*P2_D8+5.11*P2_D9+2.67*P2_D10+4.14*P2_D11+1.22*P2_D12+5.1*P2_D13+3.47*P2_D14+1.92*P2_D15+2.66*P3_D1+.95*P3_D2+3.94*P3_D3+2.04*P3_D4+2.35*P3_D5+1.42*P3_D6+3.6*P3_D7+3.17*P3_D8+1.34*P3_D9+4.51*P3_D10+.74*P3_D11+.94*P3_D12+1.98*P3_D13+4.77*P3_D14+2.04*P3_D15

# solve the problem
status = Brewery_prob.solve()
print("Brewery Problem")
print(f"status={LpStatus[status]}")

# print results
for variable in Brewery_prob.variables():
    print(f"{variable.name} = {variable.varValue}")
print(f"")
print(f"Objective = {value(Brewery_prob.objective)}")
print(f"")

# print reduced costs
for v in Brewery_prob.variables():
    print(v.name, "=", v.varValue, "\tCost =", v.dj)
print(f"")

# print shadow prices
o = [{'name':name, 'cost':c.pi, 'slack':c.slack}
    for name, c in Brewery_prob.constraints.items()]
print(pd.DataFrame(o))
print(f"")
# Out:
# Brewery Problem
# status=Optimal
# B1_P1 = 0.0
# B1_P2 = 100.0
# B1_P3 = 0.0
# B2_P1 = 0.0
# B2_P2 = 0.0
# B2_P3 = 150.0
# B3_P1 = 0.0
# B3_P2 = 0.0
# B3_P3 = 200.0
# B4_P1 = 100.0
# B4_P2 = 0.0
# B4_P3 = 0.0
# P1_D1 = 0.0
# P1_D10 = 41.0
# P1_D11 = 0.0
# P1_D12 = 42.0
# P1_D13 = 0.0
# P1_D14 = 0.0
# P1_D15 = 41.0
# P1_D2 = 0.0
# P1_D3 = 0.0
# P1_D4 = 0.0
# P1_D5 = 47.0
# P1_D6 = 0.0
# P1_D7 = 0.0
# P1_D8 = 0.0
# P1_D9 = 0.0
# P2_D1 = 48.0
# P2_D10 = 0.0
# P2_D11 = 0.0
# P2_D12 = 0.0
# P2_D13 = 0.0
# P2_D14 = 70.0
# P2_D15 = 0.0
# P2_D2 = 0.0
# P2_D3 = 0.0
# P2_D4 = 0.0
# P2_D5 = 0.0
# P2_D6 = 0.0
# P2_D7 = 64.0
# P2_D8 = 93.0
# P2_D9 = 0.0
# P3_D1 = 0.0
# P3_D10 = 0.0
# P3_D11 = 61.0
# P3_D12 = 0.0
# P3_D13 = 57.0
# P3_D14 = 0.0
# P3_D15 = 0.0
# P3_D2 = 84.0
# P3_D3 = 64.0
# P3_D4 = 106.0
# P3_D5 = 0.0
# P3_D6 = 57.0
# P3_D7 = 0.0
# P3_D8 = 0.0
# P3_D9 = 74.0
#
# Objective = 2146.9700000000003
#
# B1_P1 = 0.0 	Cost = 1.04
# B1_P2 = 100.0 	Cost = 0.0
# B1_P3 = 0.0 	Cost = 0.39
# ...

# %%
# PROBLEM 4

# define variables - # of units to ship from each brewery to packaging facility - 12 paths
B1_P1 = LpVariable("B1_P1", 0, None)
B1_P2 = LpVariable("B1_P2", 0, None)
B1_P3 = LpVariable("B1_P3", 0, None)
B2_P1 = LpVariable("B2_P1", 0, None)
B2_P2 = LpVariable("B2_P2", 0, None)
B2_P3 = LpVariable("B2_P3", 0, None)
B3_P1 = LpVariable("B3_P1", 0, None)
B3_P2 = LpVariable("B3_P2", 0, None)
B3_P3 = LpVariable("B3_P3", 0, None)
B4_P1 = LpVariable("B4_P1", 0, None)
B4_P2 = LpVariable("B4_P2", 0, None)
B4_P3 = LpVariable("B4_P3", 0, None)

# define variables - # of units to ship from each packaging facility to each demand point - 45 paths
P1_D1 = LpVariable("P1_D1", 0, None)
P1_D2 = LpVariable("P1_D2", 0, None)
P1_D3 = LpVariable("P1_D3", 0, None)
P1_D4 = LpVariable("P1_D4", 0, None)
P1_D5 = LpVariable("P1_D5", 0, None)
P1_D6 = LpVariable("P1_D6", 0, None)
P1_D7 = LpVariable("P1_D7", 0, None)
P1_D8 = LpVariable("P1_D8", 0, None)
P1_D9 = LpVariable("P1_D9", 0, None)
P1_D10 = LpVariable("P1_D10", 0, None)
P1_D11 = LpVariable("P1_D11", 0, None)
P1_D12 = LpVariable("P1_D12", 0, None)
P1_D13 = LpVariable("P1_D13", 0, None)
P1_D14 = LpVariable("P1_D14", 0, None)
P1_D15 = LpVariable("P1_D15", 0, None)
P2_D1 = LpVariable("P2_D1", 0, None)
P2_D2 = LpVariable("P2_D2", 0, None)
P2_D3 = LpVariable("P2_D3", 0, None)
P2_D4 = LpVariable("P2_D4", 0, None)
P2_D5 = LpVariable("P2_D5", 0, None)
P2_D6 = LpVariable("P2_D6", 0, None)
P2_D7 = LpVariable("P2_D7", 0, None)
P2_D8 = LpVariable("P2_D8", 0, None)
P2_D9 = LpVariable("P2_D9", 0, None)
P2_D10 = LpVariable("P2_D10", 0, None)
P2_D11 = LpVariable("P2_D11", 0, None)
P2_D12 = LpVariable("P2_D12", 0, None)
P2_D13 = LpVariable("P2_D13", 0, None)
P2_D14 = LpVariable("P2_D14", 0, None)
P2_D15 = LpVariable("P2_D15", 0, None)
P3_D1 = LpVariable("P3_D1", 0, None)
P3_D2 = LpVariable("P3_D2", 0, None)
P3_D3 = LpVariable("P3_D3", 0, None)
P3_D4 = LpVariable("P3_D4", 0, None)
P3_D5 = LpVariable("P3_D5", 0, None)
P3_D6 = LpVariable("P3_D6", 0, None)
P3_D7 = LpVariable("P3_D7", 0, None)
P3_D8 = LpVariable("P3_D8", 0, None)
P3_D9 = LpVariable("P3_D9", 0, None)
P3_D10 = LpVariable("P3_D10", 0, None)
P3_D11 = LpVariable("P3_D11", 0, None)
P3_D12 = LpVariable("P3_D12", 0, None)
P3_D13 = LpVariable("P3_D13", 0, None)
P3_D14 = LpVariable("P3_D14", 0, None)
P3_D15 = LpVariable("P3_D15", 0, None)


# define the problem - minimize total shipping costs
Brewery_prob = LpProblem("problem", LpMinimize)

# define flow constraints - brewery capacities
Brewery_prob += B1_P1+B1_P2+B1_P3 >= 100
Brewery_prob += B1_P1+B1_P2+B1_P3 <= 2000
Brewery_prob += B2_P1+B2_P2+B2_P3 >= 150
Brewery_prob += B2_P1+B2_P2+B2_P3 <= 2500
Brewery_prob += B3_P1+B3_P2+B3_P3 >= 200
Brewery_prob += B3_P1+B3_P2+B3_P3 <= 3500
Brewery_prob += B4_P1+B4_P2+B4_P3 >= 100
Brewery_prob += B4_P1+B4_P2+B4_P3 <= 2000

# define flow constraints - pkg facility capacities
Brewery_prob += B1_P1+B2_P1+B3_P1+B4_P1 >= 50
Brewery_prob += B1_P1+B2_P1+B3_P1+B4_P1 <= 500
Brewery_prob += B1_P2+B2_P2+B3_P2+B4_P2 >= 100
Brewery_prob += B1_P2+B2_P2+B3_P2+B4_P2 <= 1500
Brewery_prob += B1_P3+B2_P3+B3_P3+B4_P3 >= 150
Brewery_prob += B1_P3+B2_P3+B3_P3+B4_P3 <= 2500


# define flow constraints - demand points units ordered
Brewery_prob += P1_D1+P2_D1+P3_D1 == 48*3
Brewery_prob += P1_D2+P2_D2+P3_D2 == 84*3
Brewery_prob += P1_D3+P2_D3+P3_D3 == 64*3
Brewery_prob += P1_D4+P2_D4+P3_D4 == 106*3
Brewery_prob += P1_D5+P2_D5+P3_D5 == 47*3
Brewery_prob += P1_D6+P2_D6+P3_D6 == 57*3
Brewery_prob += P1_D7+P2_D7+P3_D7 == 64*3
Brewery_prob += P1_D8+P2_D8+P3_D8 == 93*3
Brewery_prob += P1_D9+P2_D9+P3_D9 == 74*3
Brewery_prob += P1_D10+P2_D10+P3_D10 == 41*3
Brewery_prob += P1_D11+P2_D11+P3_D11 == 61*3
Brewery_prob += P1_D12+P2_D12+P3_D12 == 42*3
Brewery_prob += P1_D13+P2_D13+P3_D13 == 57*3
Brewery_prob += P1_D14+P2_D14+P3_D14 == 70*3
Brewery_prob += P1_D15+P2_D15+P3_D15 == 41*3


# define objective function
Brewery_prob += 1.55*B1_P1+0.51*B1_P2+0.9*B1_P3+0.81*B2_P1+3.18*B2_P2+0.65*B2_P3+2.13*B3_P1+0.97*B3_P2+0.51*B3_P3+1.23*B4_P1+2.15*B4_P2+2.08*B4_P3+4.82*P1_D1+2.05*P1_D2+4.42*P1_D3+3.83*P1_D4+0.97*P1_D5+3.04*P1_D6+3.91*P1_D7+4.03*P1_D8+5.11*P1_D9+0.90*P1_D10+4.39*P1_D11+.85*P1_D12+2.81*P1_D13+3.94*P1_D14+1.04*P1_D15+1.83*P2_D1+4.03*P2_D2+3.95*P2_D3+4.21*P2_D4+4.78*P2_D5+3.2*P2_D6+1.88*P2_D7+2.96*P2_D8+5.11*P2_D9+2.67*P2_D10+4.14*P2_D11+1.22*P2_D12+5.1*P2_D13+3.47*P2_D14+1.92*P2_D15+2.66*P3_D1+.95*P3_D2+3.94*P3_D3+2.04*P3_D4+2.35*P3_D5+1.42*P3_D6+3.6*P3_D7+3.17*P3_D8+1.34*P3_D9+4.51*P3_D10+.74*P3_D11+.94*P3_D12+1.98*P3_D13+4.77*P3_D14+2.04*P3_D15

# solve the problem
status = Brewery_prob.solve()
print("Brewery Problem")
print(f"status={LpStatus[status]}")

# print results
for variable in Brewery_prob.variables():
    print(f"{variable.name} = {variable.varValue}")
print(f"")
print(f"Objective = {value(Brewery_prob.objective)}")
print(f"")

# print reduced costs
for v in Brewery_prob.variables():
    print(v.name, "=", v.varValue, "\tCost =", v.dj)
print(f"")

# print shadow prices
o = [{'name':name, 'cost':c.pi, 'slack':c.slack}
    for name, c in Brewery_prob.constraints.items()]
print(pd.DataFrame(o))
print(f"")
# Out:
# Brewery Problem
# status=Optimal
# B1_P1 = 0.0
# B1_P2 = 100.0
# B1_P3 = 0.0
# B2_P1 = 0.0
# B2_P2 = 0.0
# B2_P3 = 150.0
# B3_P1 = 0.0
# B3_P2 = 0.0
# B3_P3 = 200.0
# B4_P1 = 100.0
# B4_P2 = 0.0
# B4_P3 = 0.0
# P1_D1 = 0.0
# P1_D10 = 123.0
# P1_D11 = 0.0
# P1_D12 = 126.0
# P1_D13 = 0.0
# P1_D14 = 0.0
# P1_D15 = 123.0
# P1_D2 = 0.0
# P1_D3 = 0.0
# P1_D4 = 0.0
# P1_D5 = 141.0
# P1_D6 = 0.0
# P1_D7 = 0.0
# P1_D8 = 0.0
# P1_D9 = 0.0
# P2_D1 = 144.0
# P2_D10 = 0.0
# P2_D11 = 0.0
# P2_D12 = 0.0
# P2_D13 = 0.0
# P2_D14 = 210.0
# P2_D15 = 0.0
# P2_D2 = 0.0
# P2_D3 = 0.0
# P2_D4 = 0.0
# P2_D5 = 0.0
# P2_D6 = 0.0
# P2_D7 = 192.0
# P2_D8 = 279.0
# P2_D9 = 0.0
# P3_D1 = 0.0
# P3_D10 = 0.0
# P3_D11 = 183.0
# P3_D12 = 0.0
# P3_D13 = 171.0
# P3_D14 = 0.0
# P3_D15 = 0.0
# P3_D2 = 252.0
# P3_D3 = 192.0
# P3_D4 = 318.0
# P3_D5 = 0.0
# P3_D6 = 171.0
# P3_D7 = 0.0
# P3_D8 = 0.0
# P3_D9 = 222.0
#
# Objective = 5693.91
#
# B1_P1 = 0.0 	Cost = 1.04
# B1_P2 = 100.0 	Cost = 0.0
# B1_P3 = 0.0 	Cost = 0.39
# ...
