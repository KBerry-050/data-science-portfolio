# %%
import pandas as pd
import numpy as np

from pulp import (LpProblem, LpMaximize, LpVariable, lpSum, PULP_CBC_CMD, GLPK_CMD, LpStatus, value, GLPK)

# %%
problem = LpProblem("problem", LpMaximize)

# %%
# PRODUCTION

# 5 periods of production need to be scheduled - production requirements must be met in each period for each product
# products can be produced from either plant A or B

# Variables
widgets_plantA_P1 = LpVariable("widgets_plantA_P1", 0, None)
gadgets_plantA_P1 = LpVariable("gadgets_plantA_P1", 0, None)
flugels_plantA_P1 = LpVariable("flugels_plantA_P1", 0, None)
widgets_plantA_P2 = LpVariable("widgets_plantA_P2", 0, None)
gadgets_plantA_P2 = LpVariable("gadgets_plantA_P2", 0, None)
flugels_plantA_P2 = LpVariable("flugels_plantA_P2", 0, None)
widgets_plantA_P3 = LpVariable("widgets_plantA_P3", 0, None)
gadgets_plantA_P3 = LpVariable("gadgets_plantA_P3", 0, None)
flugels_plantA_P3 = LpVariable("flugels_plantA_P3", 0, None)
widgets_plantA_P4 = LpVariable("widgets_plantA_P4", 0, None)
gadgets_plantA_P4 = LpVariable("gadgets_plantA_P4", 0, None)
flugels_plantA_P4 = LpVariable("flugels_plantA_P4", 0, None)
widgets_plantA_P5 = LpVariable("widgets_plantA_P5", 0, None)
gadgets_plantA_P5 = LpVariable("gadgets_plantA_P5", 0, None)
flugels_plantA_P5 = LpVariable("flugels_plantA_P5", 0, None)

widgets_plantB_P1 = LpVariable("widgets_plantB_P1", 0, None)
gadgets_plantB_P1 = LpVariable("gadgets_plantB_P1", 0, None)
flugels_plantB_P1 = LpVariable("flugels_plantB_P1", 0, None)
widgets_plantB_P2 = LpVariable("widgets_plantB_P2", 0, None)
gadgets_plantB_P2 = LpVariable("gadgets_plantB_P2", 0, None)
flugels_plantB_P2 = LpVariable("flugels_plantB_P2", 0, None)
widgets_plantB_P3 = LpVariable("widgets_plantB_P3", 0, None)
gadgets_plantB_P3 = LpVariable("gadgets_plantB_P3", 0, None)
flugels_plantB_P3 = LpVariable("flugels_plantB_P3", 0, None)
widgets_plantB_P4 = LpVariable("widgets_plantB_P4", 0, None)
gadgets_plantB_P4 = LpVariable("gadgets_plantB_P4", 0, None)
flugels_plantB_P4 = LpVariable("flugels_plantB_P4", 0, None)
widgets_plantB_P5 = LpVariable("widgets_plantB_P5", 0, None)
gadgets_plantB_P5 = LpVariable("gadgets_plantB_P5", 0, None)
flugels_plantB_P5 = LpVariable("flugels_plantB_P5", 0, None)

widgets_advertising_P1 = LpVariable("widgets_advertising_P1", 0, None)    
widgets_advertising_P2 = LpVariable("widgets_advertising_P2", 0, None)
widgets_advertising_P3 = LpVariable("widgets_advertising_P3", 0, None)
widgets_advertising_P4 = LpVariable("widgets_advertising_P4", 0, None)
gadgets_advertising_P1 = LpVariable("gadgets_advertising_P1", 0, None)
gadgets_advertising_P2 = LpVariable("gadgets_advertising_P2", 0, None)
gadgets_advertising_P3 = LpVariable("gadgets_advertising_P3", 0, None)
gadgets_advertising_P4 = LpVariable("gadgets_advertising_P4", 0, None)
flugels_advertising_P1 = LpVariable("flugels_advertising_P1", 0, None)
flugels_advertising_P2 = LpVariable("flugels_advertising_P2", 0, None)
flugels_advertising_P3 = LpVariable("flugels_advertising_P3", 0, None)
flugels_advertising_P4 = LpVariable("flugels_advertising_P4", 0, None)

# constraint

problem += widgets_plantA_P1 + widgets_plantB_P1 >= 70
problem += widgets_plantA_P2 + widgets_plantB_P2 >= 125
problem += widgets_plantA_P3 + widgets_plantB_P3 >= 185
problem += widgets_plantA_P4 + widgets_plantB_P4 >= 190
problem += widgets_plantA_P5 + widgets_plantB_P5 >= 200
problem += gadgets_plantA_P1 + gadgets_plantB_P1 >= 200
problem += gadgets_plantA_P2 + gadgets_plantB_P2 >= 300
problem += gadgets_plantA_P3 + gadgets_plantB_P3 >= 295
problem += gadgets_plantA_P4 + gadgets_plantB_P4 >= 245
problem += gadgets_plantA_P5 + gadgets_plantB_P5 >= 240
problem += flugels_plantA_P1 + flugels_plantB_P1 >= 140
problem += flugels_plantA_P2 + flugels_plantB_P2 >= 175
problem += flugels_plantA_P3 + flugels_plantB_P3 >= 205
problem += flugels_plantA_P4 + flugels_plantB_P4 >= 235
problem += flugels_plantA_P5 + flugels_plantB_P5 >= 230

# Advertising attempt by adjusting demand constraint

# problem += widgets_plantA_P2 + widgets_plantB_P2 - widgets_advertising_P1 <= 125
# problem += widgets_plantA_P3 + widgets_plantB_P3 - widgets_advertising_P2 <= 185
# problem += widgets_plantA_P4 + widgets_plantB_P4 - widgets_advertising_P3 <= 190
# problem += widgets_plantA_P5 + widgets_plantB_P5 - widgets_advertising_P4 <= 200
# problem += gadgets_plantA_P2 + gadgets_plantB_P2 - gadgets_advertising_P1 <= 300
# problem += gadgets_plantA_P3 + gadgets_plantB_P3 - gadgets_advertising_P2 <= 295
# problem += gadgets_plantA_P4 + gadgets_plantB_P4 - gadgets_advertising_P3 <= 245
# problem += gadgets_plantA_P5 + gadgets_plantB_P5 - gadgets_advertising_P4 <= 240
# problem += flugels_plantA_P2 + flugels_plantB_P2 - flugels_advertising_P1 <= 279.41
# problem += flugels_plantA_P3 + flugels_plantB_P3 - flugels_advertising_P2 <= 219.03
# problem += flugels_plantA_P4 + flugels_plantB_P4 - flugels_advertising_P3 <= 279.12
# problem += flugels_plantA_P5 + flugels_plantB_P5 - flugels_advertising_P4 <= 274.69

# %%
# ADVERTISING 

# widget_ad = 160
# gadget_ad = 120
# flugel_ad = 180

# problem += ((widget_ad * (widgets_advertising_P1 + widgets_advertising_P2 + widgets_advertising_P3+ widgets_advertising_P4)) + 
#  (gadget_ad * (gadgets_advertising_P1 + gadgets_advertising_P2 + gadgets_advertising_P3 + gadgets_advertising_P4)) + 
#  (flugel_ad * (flugels_advertising_P1 + flugels_advertising_P2 + flugels_advertising_P3 + flugels_advertising_P4)))    <= 70000

# %%
# PRODUCT PRICING - FOR LATER USE (TBD)
price_widget = 2490
price_gadget = 1990
price_flugel = 2970

# %%
# RAW MATERIAL REQUIREMENTS & SHIPPING COSTS
# For each period, vendor can provide a max of 70 tons of raw material 1 and 2.5 tons of raw material 2
# equivalent to 140,000 pounds of material 1 and 5,000 pounds of material 2
# Raw material has to be used in the period that it's purchased in

# PLANT A - 
# Each Widget requires 194 pounds of Raw Material 1, 8.6 pounds of Raw Material 2, and 9.5 hours of Labor.
# Each Gadget requires 230 pounds of Raw Material 1 and 7.1 hours of Labor.
# Each Flugel requires 178 pounds of Raw Material 1, 11.6 pounds of Raw Material 2, and 11.1 hours of Labor.
# Raw material 1 - shipping cost to plant A = $1.25/pound
# Raw material 2 - shipping cost to plant A = $2.65/pound

# PLANT B - 
# Each Widget requires 188 pounds of Raw Material 1, 9.2 pounds of Raw Material 2, and 9.1 hours of Labor.
# Each Gadget requires 225 pounds of Raw Material 1 and 7.8 hours of Labor.
# Each Flugel requires 170 pounds of Raw Material 1, 10.8 pounds of Raw Material 2, and 10.6 hours of Labor.
# Raw material 1 - shipping cost to plant B = $1.45/pound
# Raw material 2 - shipping cost to plant B = $2.90/pound

problem += 194*widgets_plantA_P1 + 230*gadgets_plantA_P1 + 178*flugels_plantA_P1 + 188*widgets_plantB_P1 + 225*gadgets_plantB_P1 + 170*flugels_plantB_P1 <= 140000
problem += 194*widgets_plantA_P2 + 230*gadgets_plantA_P2 + 178*flugels_plantA_P2 + 188*widgets_plantB_P2 + 225*gadgets_plantB_P2 + 170*flugels_plantB_P2 <= 140000
problem += 194*widgets_plantA_P3 + 230*gadgets_plantA_P3 + 178*flugels_plantA_P3 + 188*widgets_plantB_P3 + 225*gadgets_plantB_P3 + 170*flugels_plantB_P3 <= 140000
problem += 194*widgets_plantA_P4 + 230*gadgets_plantA_P4 + 178*flugels_plantA_P4 + 188*widgets_plantB_P4 + 225*gadgets_plantB_P4 + 170*flugels_plantB_P4 <= 140000
problem += 194*widgets_plantA_P5 + 230*gadgets_plantA_P5 + 178*flugels_plantA_P5 + 188*widgets_plantB_P5 + 225*gadgets_plantB_P5 + 170*flugels_plantB_P5 <= 140000
problem += 8.6*widgets_plantA_P1 + 11.6*flugels_plantA_P1 + 9.2*widgets_plantB_P1 + 10.8*flugels_plantB_P1 <= 5000
problem += 8.6*widgets_plantA_P2 + 11.6*flugels_plantA_P2 + 9.2*widgets_plantB_P2 + 10.8*flugels_plantB_P2 <= 5000
problem += 8.6*widgets_plantA_P3 + 11.6*flugels_plantA_P3 + 9.2*widgets_plantB_P3 + 10.8*flugels_plantB_P3 <= 5000
problem += 8.6*widgets_plantA_P4 + 11.6*flugels_plantA_P4 + 9.2*widgets_plantB_P4 + 10.8*flugels_plantB_P4 <= 5000
problem += 8.6*widgets_plantA_P5 + 11.6*flugels_plantA_P5 + 9.2*widgets_plantB_P5 + 10.8*flugels_plantB_P5 <= 5000

shippingcost_a = (1.25*(194*widgets_plantA_P1 + 230*gadgets_plantA_P1 + 178*flugels_plantA_P1 
                        + 194*widgets_plantA_P2 + 230*gadgets_plantA_P2 + 178*flugels_plantA_P2
                        + 194*widgets_plantA_P3 + 230*gadgets_plantA_P3 + 178*flugels_plantA_P3
                        + 194*widgets_plantA_P4 + 230*gadgets_plantA_P4 + 178*flugels_plantA_P4
                        + 194*widgets_plantA_P5 + 230*gadgets_plantA_P5 + 178*flugels_plantA_P5)
                + 2.65*(8.6*widgets_plantA_P1 + 11.6*flugels_plantA_P1 + 8.6*widgets_plantA_P2 + 11.6*flugels_plantA_P2
                        + 8.6*widgets_plantA_P3 + 11.6*flugels_plantA_P3 + 8.6*widgets_plantA_P4 + 11.6*flugels_plantA_P4
                        + 8.6*widgets_plantA_P5 + 11.6*flugels_plantA_P5))

shippingcost_b = (1.45*(188*widgets_plantB_P1 + 225*gadgets_plantB_P1 + 170*flugels_plantB_P1
                        + 188*widgets_plantB_P2 + 225*gadgets_plantB_P2 + 170*flugels_plantB_P2
                        + 188*widgets_plantB_P3 + 225*gadgets_plantB_P3 + 170*flugels_plantB_P3
                        + 188*widgets_plantB_P4 + 225*gadgets_plantB_P4 + 170*flugels_plantB_P4
                        + 188*widgets_plantB_P5 + 225*gadgets_plantB_P5 + 170*flugels_plantB_P5)
                + 2.9*(9.2*widgets_plantB_P1 + 10.8*flugels_plantB_P1 + 9.2*widgets_plantB_P2 + 10.8*flugels_plantB_P2
                        + 9.2*widgets_plantB_P3 + 10.8*flugels_plantB_P3 + 9.2*widgets_plantB_P4 + 10.8*flugels_plantB_P4
                        + 9.2*widgets_plantB_P5 + 10.8*flugels_plantB_P5))

# %%
# LABOR REQUIREMENTS

# PLANT A - 
# Regular time labor is limited to 2500 hrs in each period. Overtime can be scheduled if necessary
# PERIOD 1 & 2 - Labor costs are $11/hr for regular time, $16.50/hr overtime
# Labor costs are expected to rise by 5% at the end of period 2
# PERIOD 3, 4 5 - Labor costs are $11.55/hr for regular time, $17.325/hr overtime

# PLANT B - 
# Regular time labor is limited to 3800 hrs in each period. Overtime can be scheduled if necessary
# PERIOD 1 & 2 - Labor costs are $11/hr for regular time, $16.50/hr overtime
# Labor costs are expected to rise by 10% at the end of period 2
# PERIOD 3, 4 5 - Labor costs are $12.1/hr for regular time, $18.15/hr overtime

reghours_plantA_P1 = LpVariable("reghours_plantA_P1", 0, 2500)
reghours_plantA_P2 = LpVariable("reghours_plantA_P2", 0, 2500)
reghours_plantA_P3 = LpVariable("reghours_plantA_P3", 0, 2500)
reghours_plantA_P4 = LpVariable("reghours_plantA_P4", 0, 2500)
reghours_plantA_P5 = LpVariable("reghours_plantA_P5", 0, 2500)
overtime_plantA_P1 = LpVariable("overtime_plantA_P1", 0, None) 
overtime_plantA_P2 = LpVariable("overtime_plantA_P2", 0, None) 
overtime_plantA_P3 = LpVariable("overtime_plantA_P3", 0, None) 
overtime_plantA_P4 = LpVariable("overtime_plantA_P4", 0, None) 
overtime_plantA_P5 = LpVariable("overtime_plantA_P5", 0, None) 

reghours_plantB_P1 = LpVariable("reghours_plantB_P1", 0, 3800)
reghours_plantB_P2 = LpVariable("reghours_plantB_P2", 0, 3800)
reghours_plantB_P3 = LpVariable("reghours_plantB_P3", 0, 3800)
reghours_plantB_P4 = LpVariable("reghours_plantB_P4", 0, 3800)
reghours_plantB_P5 = LpVariable("reghours_plantB_P5", 0, 3800)
overtime_plantB_P1 = LpVariable("overtime_plantB_P1", 0, None) 
overtime_plantB_P2 = LpVariable("overtime_plantB_P2", 0, None) 
overtime_plantB_P3 = LpVariable("overtime_plantB_P3", 0, None) 
overtime_plantB_P4 = LpVariable("overtime_plantB_P4", 0, None) 
overtime_plantB_P5 = LpVariable("overtime_plantB_P5", 0, None) 

problem += 9.5*widgets_plantA_P1 + 7.1*gadgets_plantA_P1 + 11.1*flugels_plantA_P1 <= reghours_plantA_P1 + overtime_plantA_P1 
problem += 9.5*widgets_plantA_P2 + 7.1*gadgets_plantA_P2 + 11.1*flugels_plantA_P2 <= reghours_plantA_P2 + overtime_plantA_P2 
problem += 9.5*widgets_plantA_P3 + 7.1*gadgets_plantA_P3 + 11.1*flugels_plantA_P3 <= reghours_plantA_P3 + overtime_plantA_P3 
problem += 9.5*widgets_plantA_P4 + 7.1*gadgets_plantA_P4 + 11.1*flugels_plantA_P4 <= reghours_plantA_P4 + overtime_plantA_P4 
problem += 9.5*widgets_plantA_P5 + 7.1*gadgets_plantA_P5 + 11.1*flugels_plantA_P5 <= reghours_plantA_P5 + overtime_plantA_P5

problem += 9.1*widgets_plantB_P1 + 7.8*gadgets_plantB_P1 + 10.6*flugels_plantB_P1 <= reghours_plantB_P1 + overtime_plantB_P1  
problem += 9.1*widgets_plantB_P2 + 7.8*gadgets_plantB_P2 + 10.6*flugels_plantB_P2 <= reghours_plantB_P2 + overtime_plantB_P2
problem += 9.1*widgets_plantB_P3 + 7.8*gadgets_plantB_P3 + 10.6*flugels_plantB_P3 <= reghours_plantB_P3 + overtime_plantB_P3
problem += 9.1*widgets_plantB_P4 + 7.8*gadgets_plantB_P4 + 10.6*flugels_plantB_P4 <= reghours_plantB_P4 + overtime_plantB_P4
problem += 9.1*widgets_plantB_P5 + 7.8*gadgets_plantB_P5 + 10.6*flugels_plantB_P5 <= reghours_plantB_P5 + overtime_plantB_P5

laborcost_a = (11*reghours_plantA_P1 + 11*reghours_plantA_P2 + 11.55*reghours_plantA_P3 + 11.55*reghours_plantA_P4
    + 11.55*reghours_plantA_P5 + 16.5*overtime_plantA_P1 + 16.5*overtime_plantA_P2 + 17.325*overtime_plantA_P3 
    + 17.325*overtime_plantA_P4 + 17.325*overtime_plantA_P5)
    
laborcost_b = (11*reghours_plantB_P1 + 11*reghours_plantB_P2 + 12.1*reghours_plantB_P3 + 12.1*reghours_plantB_P4
    + 12.1*reghours_plantB_P5 + 16.5*overtime_plantB_P1 + 16.5*overtime_plantB_P2 + 18.15*overtime_plantB_P3 
    + 18.15*overtime_plantB_P4 + 18.15*overtime_plantB_P5)

# %%
# INVENTORY REQUIREMENTS
# PLANT A - Inventory area can store a maximum of 70 units
# PLANT B - Inventory area can store a maximum of 50 units

# number of products in in inventory each period
widgets_plantA_P1_inv = LpVariable("widgets_plantA_P1_inv", 0, None)
gadgets_plantA_P1_inv = LpVariable("gadgets_plantA_P1_inv", 0, None)
flugels_plantA_P1_inv = LpVariable("flugels_plantA_P1_inv", 0, None)
widgets_plantA_P2_inv = LpVariable("widgets_plantA_P2_inv", 0, None)
gadgets_plantA_P2_inv = LpVariable("gadgets_plantA_P2_inv", 0, None)
flugels_plantA_P2_inv = LpVariable("flugels_plantA_P2_inv", 0, None)
widgets_plantA_P3_inv = LpVariable("widgets_plantA_P3_inv", 0, None)
gadgets_plantA_P3_inv = LpVariable("gadgets_plantA_P3_inv", 0, None)
flugels_plantA_P3_inv = LpVariable("flugels_plantA_P3_inv", 0, None)
widgets_plantA_P4_inv = LpVariable("widgets_plantA_P4_inv", 0, None)
gadgets_plantA_P4_inv = LpVariable("gadgets_plantA_P4_inv", 0, None)
flugels_plantA_P4_inv = LpVariable("flugels_plantA_P4_inv", 0, None)
widgets_plantA_P5_inv = LpVariable("widgets_plantA_P5_inv", 0, None)
gadgets_plantA_P5_inv = LpVariable("gadgets_plantA_P5_inv", 0, None)
flugels_plantA_P5_inv = LpVariable("flugels_plantA_P5_inv", 0, None)

widgets_plantB_P1_inv = LpVariable("widgets_plantB_P1_inv", 0, None)
gadgets_plantB_P1_inv = LpVariable("gadgets_plantB_P1_inv", 0, None)
flugels_plantB_P1_inv = LpVariable("flugels_plantB_P1_inv", 0, None)
widgets_plantB_P2_inv = LpVariable("widgets_plantB_P2_inv", 0, None)
gadgets_plantB_P2_inv = LpVariable("gadgets_plantB_P2_inv", 0, None)
flugels_plantB_P2_inv = LpVariable("flugels_plantB_P2_inv", 0, None)
widgets_plantB_P3_inv = LpVariable("widgets_plantB_P3_inv", 0, None)
gadgets_plantB_P3_inv = LpVariable("gadgets_plantB_P3_inv", 0, None)
flugels_plantB_P3_inv = LpVariable("flugels_plantB_P3_inv", 0, None)
widgets_plantB_P4_inv = LpVariable("widgets_plantB_P4_inv", 0, None)
gadgets_plantB_P4_inv = LpVariable("gadgets_plantB_P4_inv", 0, None)
flugels_plantB_P4_inv = LpVariable("flugels_plantB_P4_inv", 0, None)
widgets_plantB_P5_inv = LpVariable("widgets_plantB_P5_inv", 0, None)
gadgets_plantB_P5_inv = LpVariable("gadgets_plantB_P5_inv", 0, None)
flugels_plantB_P5_inv = LpVariable("flugels_plantB_P5_inv", 0, None)

problem += widgets_plantA_P1_inv + gadgets_plantA_P1_inv + flugels_plantA_P1_inv <= 70
problem += widgets_plantA_P2_inv + gadgets_plantA_P2_inv + flugels_plantA_P2_inv <= 70
problem += widgets_plantA_P3_inv + gadgets_plantA_P3_inv + flugels_plantA_P3_inv <= 70
problem += widgets_plantA_P4_inv + gadgets_plantA_P4_inv + flugels_plantA_P4_inv <= 70
problem += widgets_plantA_P5_inv + gadgets_plantA_P5_inv + flugels_plantA_P5_inv <= 70

problem += widgets_plantB_P1_inv + gadgets_plantB_P1_inv + flugels_plantB_P1_inv <= 50
problem += widgets_plantB_P2_inv + gadgets_plantB_P2_inv + flugels_plantB_P2_inv <= 50
problem += widgets_plantB_P3_inv + gadgets_plantB_P3_inv + flugels_plantB_P3_inv <= 50
problem += widgets_plantB_P4_inv + gadgets_plantB_P4_inv + flugels_plantB_P4_inv <= 50
problem += widgets_plantB_P5_inv + gadgets_plantB_P5_inv + flugels_plantB_P5_inv <= 50

invcost_a = (7.5*(widgets_plantA_P1_inv + widgets_plantA_P2_inv + widgets_plantA_P3_inv + widgets_plantA_P4_inv + widgets_plantA_P5_inv)
       + 5.5*(gadgets_plantA_P1_inv + gadgets_plantA_P2_inv + gadgets_plantA_P3_inv + gadgets_plantA_P4_inv + gadgets_plantA_P5_inv)
       + 6.5*(flugels_plantA_P1_inv + flugels_plantA_P2_inv + flugels_plantA_P3_inv + flugels_plantA_P4_inv + flugels_plantA_P5_inv))

invcost_b = (7.8*(widgets_plantB_P1_inv + widgets_plantB_P2_inv + widgets_plantB_P3_inv + widgets_plantB_P4_inv + widgets_plantB_P5_inv)
       + 5.7*(gadgets_plantB_P1_inv + gadgets_plantB_P2_inv + gadgets_plantB_P3_inv + gadgets_plantB_P4_inv + gadgets_plantB_P5_inv)
       + 7*(flugels_plantB_P1_inv + flugels_plantB_P2_inv + flugels_plantB_P3_inv + flugels_plantB_P4_inv + flugels_plantB_P5_inv))

# %%
# TRANSPORTATION COSTS

# number of products produced each period - number of products in the inventory each period
widgets_plantA_P1_shipped = widgets_plantA_P1 - widgets_plantA_P1_inv
gadgets_plantA_P1_shipped = gadgets_plantA_P1 - gadgets_plantA_P1_inv
flugels_plantA_P1_shipped = flugels_plantA_P1 - flugels_plantA_P1_inv
widgets_plantA_P2_shipped = widgets_plantA_P2 - widgets_plantA_P2_inv
gadgets_plantA_P2_shipped = gadgets_plantA_P2 - gadgets_plantA_P2_inv
flugels_plantA_P2_shipped = flugels_plantA_P2 - flugels_plantA_P2_inv
widgets_plantA_P3_shipped = widgets_plantA_P3 - widgets_plantA_P3_inv
gadgets_plantA_P3_shipped = gadgets_plantA_P3 - gadgets_plantA_P3_inv
flugels_plantA_P3_shipped = flugels_plantA_P3 - flugels_plantA_P3_inv
widgets_plantA_P4_shipped = widgets_plantA_P4 - widgets_plantA_P4_inv
gadgets_plantA_P4_shipped = gadgets_plantA_P4 - gadgets_plantA_P4_inv
flugels_plantA_P4_shipped = flugels_plantA_P4 - flugels_plantA_P4_inv
widgets_plantA_P5_shipped = widgets_plantA_P5 - widgets_plantA_P5_inv
gadgets_plantA_P5_shipped = gadgets_plantA_P5 - gadgets_plantA_P5_inv
flugels_plantA_P5_shipped = flugels_plantA_P5 - flugels_plantA_P5_inv

widgets_plantB_P1_shipped = widgets_plantB_P1 - widgets_plantB_P1_inv
gadgets_plantB_P1_shipped = gadgets_plantB_P1 - gadgets_plantB_P1_inv
flugels_plantB_P1_shipped = flugels_plantB_P1 - flugels_plantA_P1_inv
widgets_plantB_P2_shipped = widgets_plantB_P2 - widgets_plantB_P2_inv
gadgets_plantB_P2_shipped = gadgets_plantB_P2 - gadgets_plantB_P2_inv
flugels_plantB_P2_shipped = flugels_plantB_P2 - flugels_plantB_P2_inv
widgets_plantB_P3_shipped = widgets_plantB_P3 - widgets_plantB_P3_inv
gadgets_plantB_P3_shipped = gadgets_plantB_P3 - gadgets_plantB_P3_inv
flugels_plantB_P3_shipped = flugels_plantB_P3 - flugels_plantB_P3_inv
widgets_plantB_P4_shipped = widgets_plantB_P4 - widgets_plantB_P4_inv
gadgets_plantB_P4_shipped = gadgets_plantB_P4 - gadgets_plantB_P4_inv
flugels_plantB_P4_shipped = flugels_plantB_P4 - flugels_plantB_P4_inv
widgets_plantB_P5_shipped = widgets_plantB_P5 - widgets_plantB_P5_inv
gadgets_plantB_P5_shipped = gadgets_plantB_P5 - gadgets_plantB_P5_inv
flugels_plantB_P5_shipped = flugels_plantB_P5 - flugels_plantB_P5_inv


# transportation cost from plants A and B

transportationcost_a = (6.3*(widgets_plantA_P1_shipped + widgets_plantA_P2_shipped + widgets_plantA_P3_shipped + widgets_plantA_P4_shipped + widgets_plantA_P5_shipped)
                  + 4.6*(gadgets_plantA_P1_shipped + gadgets_plantA_P2_shipped + gadgets_plantA_P3_shipped + gadgets_plantA_P4_shipped + gadgets_plantA_P5_shipped)
                  + 5.5*(flugels_plantA_P1_shipped + flugels_plantA_P2_shipped + flugels_plantA_P3_shipped + flugels_plantA_P4_shipped + flugels_plantA_P5_shipped))

transportationcost_b = (6.5*(widgets_plantB_P1_shipped + widgets_plantB_P2_shipped + widgets_plantB_P3_shipped + widgets_plantB_P4_shipped + widgets_plantB_P5_shipped)
                  + 5*(gadgets_plantB_P1_shipped + gadgets_plantB_P2_shipped + gadgets_plantB_P3_shipped + gadgets_plantB_P4_shipped + gadgets_plantB_P5_shipped)
                  + 5.7*(flugels_plantB_P1_shipped + flugels_plantB_P2_shipped + flugels_plantB_P3_shipped + flugels_plantB_P4_shipped + flugels_plantB_P5_shipped))

# %%
# objetive - maximize profit:
# sells - advertising cost - raw material shipping cost - labor cost - inventory cost - transportation cost 

problem += (price_widget*(widgets_plantA_P1_shipped + widgets_plantA_P2_shipped + widgets_plantA_P3_shipped + widgets_plantA_P4_shipped + widgets_plantA_P5_shipped
                          + widgets_plantB_P1_shipped + widgets_plantB_P2_shipped + widgets_plantB_P3_shipped + widgets_plantB_P4_shipped + widgets_plantB_P5_shipped)
            + price_gadget*(gadgets_plantA_P1_shipped + gadgets_plantA_P2_shipped + gadgets_plantA_P3_shipped + gadgets_plantA_P4_shipped + gadgets_plantA_P5_shipped
                            + gadgets_plantB_P1_shipped + gadgets_plantB_P2_shipped + gadgets_plantB_P3_shipped + gadgets_plantB_P4_shipped + gadgets_plantB_P5_shipped)
            + price_flugel*(flugels_plantA_P1_shipped + flugels_plantA_P2_shipped + flugels_plantA_P3_shipped + flugels_plantA_P4_shipped + flugels_plantA_P5_shipped
                            + flugels_plantB_P1_shipped + flugels_plantB_P2_shipped + flugels_plantB_P3_shipped + flugels_plantB_P4_shipped + flugels_plantB_P5_shipped)
           ) - (shippingcost_a + shippingcost_b + laborcost_a + laborcost_b + invcost_a + invcost_b + transportationcost_a + transportationcost_b
#                ) - (widget_ad * (widgets_advertising_P1 + widgets_advertising_P2 + widgets_advertising_P3+ widgets_advertising_P4)
#                      + gadget_ad * (gadgets_advertising_P1 + gadgets_advertising_P2 + gadgets_advertising_P3 + gadgets_advertising_P4)
#                      + flugel_ad * (flugels_advertising_P1 + flugels_advertising_P2 + flugels_advertising_P3 + flugels_advertising_P4)
                    )

status = problem.solve()
LpStatus[status]
# Out:
# 'Optimal'

# %%
# PLACEHOLDER FOR SENSITIVITY ANALYSIS

print(value(problem.objective))
# Out:
# 7491839.296150201

# %%
# Solve the Problem
problem.writeLP("NU_Industries.lp")
problem.solve(GLPK(options=['--ranges NU_Industries.sen']))

for variable in problem.variables():
    if variable.varValue > 0:
        print(f"{variable.name} = {variable.varValue}")
    
print(f"Total Profit = {value(problem.objective)}")
print(f"")
# Out:
# flugels_advertising_P1 = 0.00176471
# flugels_plantB_P1 = 407.222
# flugels_plantB_P2 = 279.412
# flugels_plantB_P3 = 219.028
# flugels_plantB_P4 = 279.116
# flugels_plantB_P5 = 274.69
# gadgets_plantA_P1 = 248.662
# gadgets_plantA_P2 = 300.0
# gadgets_plantA_P3 = 295.0
# gadgets_plantA_P4 = 245.0
# gadgets_plantA_P5 = 240.0
# overtime_plantB_P1 = 516.556
# overtime_plantB_P2 = 299.265
# overtime_plantB_P4 = 159.148
# overtime_plantB_P5 = 169.227
# reghours_plantA_P1 = 2430.5
# reghours_plantA_P2 = 2130.0
# reghours_plantA_P3 = 2308.71
# reghours_plantA_P4 = 2500.0
# reghours_plantA_P5 = 2500.0
# reghours_plantB_P1 = 3800.0
# reghours_plantB_P2 = 3800.0
# reghours_plantB_P3 = 3800.0
# reghours_plantB_P4 = 3800.0
# reghours_plantB_P5 = 3800.0
# widgets_plantA_P1 = 70.0
# widgets_plantA_P3 = 22.5487
# widgets_plantA_P4 = 80.0526
# widgets_plantA_P5 = 83.7895
# widgets_plantB_P2 = 125.0
# widgets_plantB_P3 = 162.451
# widgets_plantB_P4 = 109.947
# widgets_plantB_P5 = 116.211
# ...

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\richd\Downloads
